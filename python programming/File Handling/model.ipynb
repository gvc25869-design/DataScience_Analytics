# %%
var = open("Database.txt","r")
print (var)
# Out:
# <_io.TextIOWrapper name='Database.txt' mode='r' encoding='utf-8'>

# %%
var.read()
# Out:
# 'Hello Welcome to the World of Python Programming'

# %%
with open('Database.txt', encoding="utf-8") as f:
    data = f.read()
    print(data)
# Out:
# Hello Welcome to the World of Python Programming

# %%
with open("Database.txt", encoding = "utf-8") as f:
    data = f.readline()
    data1 = f.readline()
    data2 = f.readline()
    print(data)
    print(data1)
    print(data2)
# Out:
# Hello Welcome to the World of Python Programming
#
# India is MY Country
#
# I am Hungry

# %%
with open("Database.txt","a") as f:
    var1 = f.write("adadsdasdffg jbjbjjjbjbj")
    print(var1)
# Out:
# 24

# %%
with open("Database.txt","a")  as f:
    var1 = f.writelines("yeaaaa")
    print(var1)
# Out:
# None

# %%
# try and except block
def division(): # Function definition
    try:
        number1 = float(input("enter the first number: "))
        number2 = float(input("enter the second number: "))

        ans = number1/number2
        print(ans)

    except:
        print("Zero Division Error")
        
division() # Function calling
# Out:
# Zero Division Error
